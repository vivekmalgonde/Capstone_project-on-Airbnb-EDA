# %% [markdown]
# # **🌏CAPSTONE PROJECT ON Airbnb BOOKING ANALYSIS🌏**
#
# ---
#
#
#
# ---

# %% [markdown]
# ## **Airbnb project**
#
#
#
# ---

# %% [markdown]
# ![airbnb.png](data:image/png;base64,...)

# %% [markdown]
# ## <b> Since 2008, guests and hosts have used Airbnb to expand on traveling possibilities and present a more unique, personalized way of experiencing the world. Today, Airbnb became one of a kind service that is used and recognized by the whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data - data that can be analyzed and used for security, business decisions, understanding of customers' and providers' (hosts) behavior and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more. </b>
#
# ## <b>This dataset has around 49,000 observations in it with 16 columns and it is a mix between categorical and numeric values. </b>
#
# ## <b> Explore and analyze the data to discover key understandings (not limited to these) such as :
# * What can we learn about different hosts and areas?
# * What can we learn from predictions? (ex: locations, prices, reviews, etc)
# * Which hosts are the busiest and why?
# * Is there any noticeable difference of traffic among different areas and what could be the reason for it? </b>

# %% [markdown]
# ###💠**INITIAL SETUP**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ###💠 **NOW MOUNT YOUR DATA FROM GOOGLE DRIVE**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##💠**Now copy the file path from your google grive to get access of given data**

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/alma better/capstone project/Airbnb NYC 2019.csv')

# %% [markdown]
# ###💠**Now checking the data whether it is mounted correctly or not**

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ##💠**Getting up on important data by looking the important information**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# 💠### **In above information you can see that there are 48895 entries and 16 columns**
# ### In this Data frame you cn see there are many null values and missing values in
# ### different rows and we need to clean those

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# # Drop the columns like name,host_name and last review

# %%
df.drop(['host_name','name','last_review'],inplace=True,axis=1)

# %%
#checking the data after implimentation of drop function

# %% [markdown]
# 💠**Last_review** and **reviews_per_month** have the same number of NaN values which means certain properties were not rated at all hence last_review has no date and reviews_per_month has no data
#
# ---
#
#
#
# ---

# %%
df.isnull().sum()
# Out:
# id                                    0
# host_id                               0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# 💠**Filling up the null value with 0**
#
# ---
#
#
#
# ---

# %%
df.fillna({'reviews_per_month':0},inplace=True)

# %%
df.isnull().sum()
# Out:
# id                                0
# host_id                           0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   host_id                         48895 non-null  int64
#  2   neighbourhood_group             48895 non-null  object
#  3   neighbourhood                   48895 non-null  object
#  4   latitude                        48895 non-null  float64
#  5   longitude                       48895 non-null  float64
#  6   room_type                       48895 non-null  object
#  7   price                           48895 non-null  int64
#  8   minimum_nights                  48895 non-null  int64
#  9   number_of_reviews               48895 non-null  int64
#  10  reviews_per_month               48895 non-null  float64
#  11  calculated_host_listings_count  48895 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       48895.000000
# mean         7.029962          23.274466           1.090910
# std         20.510550          44.550582           1.597283
# ...

# %% [markdown]
# 💠**Minimum price is zero which is not possible .**

# %%
df[df['price']==0]
# Out:
#              id    host_id neighbourhood_group       neighbourhood  latitude  \
# 23161  18750597    8993084            Brooklyn  Bedford-Stuyvesant  40.69023
# 25433  20333471  131697576               Bronx     East Morrisania  40.83296
# 25634  20523843   15787004            Brooklyn            Bushwick  40.69467
# 25753  20608117    1641537            Brooklyn          Greenpoint  40.72462
# 25778  20624541   10132166            Brooklyn        Williamsburg  40.70838
# 25794  20639628   86327101            Brooklyn  Bedford-Stuyvesant  40.68173
# 25795  20639792   86327101            Brooklyn  Bedford-Stuyvesant  40.68279
# 25796  20639914   86327101            Brooklyn  Bedford-Stuyvesant  40.68258
# 26259  20933849   13709292           Manhattan         Murray Hill  40.75091
# 26841  21291569  101970559            Brooklyn            Bushwick  40.69211
# 26866  21304320  101970559            Brooklyn            Bushwick  40.69166
#
# ...

# %%
# A function for price_correction
def price_correction(x):
    if x==0:
        return 100
    else:
        return x

# %%
df['price']=df['price'].apply(price_correction)

# %%
df['price'].apply(price_correction)
# Out:
# 0        149
# 1        225
# 2        150
# 3         89
# 4         80
#         ...
# 48890     70
# 48891     40
# 48892    115
# 48893     55
# 48894     90
# Name: price, Length: 48895, dtype: int64

# %%
df[df['price']==0]
# Out:
# Empty DataFrame
# Columns: [id, host_id, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.743184
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.144546
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420     10.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       48895.000000
# mean         7.029962          23.274466           1.090910
# std         20.510550          44.550582           1.597283
# ...

# %% [markdown]
# 💠**In this data you can see that max minimum nights is 1250 it is also not
# relevant**

# %%
def minimum_nights_correction(x):
  if x>365:
    return 365
  else:
    return x

# %%
df['minimum_nights']=df['minimum_nights'].apply(minimum_nights_correction)

# %%
df[df['minimum_nights']==365]
# Out:
#              id    host_id neighbourhood_group       neighbourhood  latitude  \
# 700      258690    1359611           Manhattan             Chelsea  40.74618
# 754      271694    1387370           Manhattan             Midtown  40.75282
# 1305     568684    2798644            Brooklyn            Bushwick  40.70202
# 1449     649561    3260084           Manhattan             Chelsea  40.75164
# 2150     992977    4000059            Brooklyn          Park Slope  40.67359
# 2831    1586935    8457613           Manhattan            Gramercy  40.73494
# 2854    1615764    6676776           Manhattan   Battery Park City  40.71239
# 3398    2037951    4191006           Manhattan        West Village  40.73858
# 3945    2454507    9991763           Manhattan  Financial District  40.70781
# 4372    2942732     160337           Manhattan  Washington Heights  40.83549
# 4437    3029690    7245581           Manhattan             Chelsea  40.74873
# ...

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.743184
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.144546
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420     10.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       48895.000000
# mean         6.942980          23.274466           1.090910
# std         17.530294          44.550582           1.597283
# ...

# %% [markdown]
# # **⚡ NOW THE DATA IS CLEAN AND IS FIT FOR FURTHER OPERATION LIKE DATA VIZUALIZATION**

# %% [markdown]
# #**⚡ CORRELATION MATRIX FORMATE**

# %%
plt.figure(figsize=(20,10))
title = 'Correlation matrix of numerical variables'
sns.heatmap(df.corr(method='pearson'),cmap='nipy_spectral',annot=True, square=True)
plt.title(title)
plt.show()

# %% [markdown]
# 💠In this heatmap you can see that **number_of_reviews** and **reviews_per_month** as well as host_id and id are highly correlated with each other

# %%
df.columns
# Out:
# Index(['id', 'host_id', 'neighbourhood_group', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %% [markdown]
# ## ⚡ **ANALYSING THE COLUMN 'neighbourhood_group' BY USINGB BAR GRAPH**

# %%
df['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
neighbourhood_group_counts=df['neighbourhood_group'].value_counts()
neighbourhood_group_counts
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %%
neighbourhood_group_counts
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %%
neighbourhood_group_counts=pd.DataFrame(data=neighbourhood_group_counts)
neighbourhood_group_counts.reset_index(inplace=True)
neighbourhood_group_counts.rename(columns={'index':'Neighbourhood_Group','neighbourhood_group':'Counts'},
                              inplace=True)

# %%
neighbourhood_group_counts
# Out:
#   Neighbourhood_Group  Counts
# 0           Manhattan   21661
# 1            Brooklyn   20104
# 2              Queens    5666
# 3               Bronx    1091
# 4       Staten Island     373

# %%
fig_1=sns.barplot(x=neighbourhood_group_counts['Neighbourhood_Group'],y=neighbourhood_group_counts['Counts'])
fig_1.set_title('Listings in Each Neighbourhood')
fig_1.set_xlabel('Neighbourhood_Group')
fig_1.set_ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# 💠From the above bar graph we come to that airbnb have maximum number of hotels in **Manhattan** followed by **Brooklyn ,Queens ,Bronx and Staten Island.**

# %% [markdown]
# # **ANALYSIS ROOM TYPE LOCATION PER NEIGHBOURHOOD GROUP**

# %%
fig_2=sns.countplot(x='neighbourhood_group',hue='room_type', data=df);
title = 'Room type location per Neighbourhood Group'
plt.title(title)
plt.show()

# %% [markdown]
# 💠From the above graph it can be observed that shared rooms have less listing in each of neighbourhood groups

# %% [markdown]
# #**⚡ANALYSING PRICE ATTRIBUTES**

# %% [markdown]
# ##◼ ANALYSING neighbourhood_group with Price

# %%
plt.style.use( 'dark_background' )

price_500 = df[df.price <700]
plt.figure(figsize=(10,6))
plt.title("PRICE FOR EACH NEIGHBOURHOOD GROUP")
sns.boxplot(y= 'price',x= 'neighbourhood_group',data=price_500)
plt.show()

# %% [markdown]
# 💠From the above Box Plot we can see that **Manhattam** is the most expensive destination immediatly followed by **Brooklyn**.
#
# **Queens, staten island and Bronx**, are having price range less as compaired to other two

# %% [markdown]
# ##⚡**ANALYSING THE RELATION BETWEEN NEIGHBOURHOOD GROUP AND PRICE.**

# %%
neigh_price_group = df.groupby(['neighbourhood_group']).agg({'price':'median'}).reset_index()
neigh_price_group
# Out:
#   neighbourhood_group  price
# 0               Bronx   65.0
# 1            Brooklyn   90.0
# 2           Manhattan  150.0
# 3              Queens   75.0
# 4       Staten Island   75.0

# %%
fig_3 = sns.barplot(x = 'neighbourhood_group',y = 'price',data = neigh_price_group)
fig_3.set_title(' MEDIAN PRICE v/s NEIGHBOURHOOD GROUP')
fig_3.set_xlabel('Neighnourhood Group')
fig_3.set_ylabel("Median Price")
plt.show()

# %% [markdown]
# ####💠We can observe that **Manhattan** is having the highest median price,followed by **Brooklyn**.

# %% [markdown]
# #⚡ **The scatter plot**

# %%
title='Map of Neighbourhood group locations'
sns.set(rc={"figure.figsize":(10, 6)})
fig_3=sns.scatterplot(x=df['longitude'],y=df['latitude'],hue=df['neighbourhood_group']).set_title(title)
plt.show()

# %% [markdown]
# ##**⚡ANALYSING THE RELATION BETWEEN price and room_type**

# %%
fig_4=sns.barplot(x='room_type',y='price',data=df)
fig_4.set_title('PRICE V/S ROOM_TYPE ')
fig_4.set_xlabel('ROOM_TYPE')
fig_4.set_ylabel('PRICE')
# Out:
# Text(0, 0.5, 'PRICE')

# %% [markdown]
# 💠From the above barplot we can observe that:
#
# Shared Room have lower price.
# Entire home/Appartment have the Highest Price.

# %% [markdown]
# ✅**ANALYSING PRICE WITH VARIOUS OTHER FACTORS**

# %% [markdown]
# ## 1.  **Minimum nights v/s price**

# %%
sns.relplot(x='minimum_nights',y='price',hue='room_type',data=df,kind='scatter')
plt.title('reviews _per_month v/s price')

plt.show()

# %% [markdown]
# ## 2. **No of reviews v/s price**

# %%
sns.relplot(x='number_of_reviews',y='price',hue='room_type',data=df)
plt.title('no_of_reviews v/s price')
plt.show()

# %% [markdown]
#
#
# # 3.   **Calculated host listings count v/s price**

# %%
sns.relplot(x='calculated_host_listings_count',y='price',hue='room_type',data=df)
plt.title("calculated_host_listings_count v/s price")
plt.show()

# %% [markdown]
# ## 4. **Reviews per month v/s price**

# %%
sns.relplot(x="reviews_per_month",y='price',hue='room_type',data=df)
plt.title('reviews _per_month v/s price')
plt.show()

# %% [markdown]
# 5.      Availability 365 v/s price

# %%
sns.relplot(x='availability_365',y='price',hue='room_type',data=df)
plt.title("calculated_host_listings_count v/s price")
plt.show()

# %% [markdown]
# ## ⚡ **ANALYSING THE HIGHEST HOST ID**

# %%
df.columns
# Out:
# Index(['id', 'host_id', 'neighbourhood_group', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %% [markdown]
# # ▶Considering top 20 hosts

# %%
top_host_id=df['host_id'].value_counts().head(20)
top_host_id
# Out:
# 219517861    327
# 107434423    232
# 30283594     121
# 137358866    103
# 16098958      96
# 12243051      96
# 61391963      91
# 22541573      87
# 200380610     65
# 7503643       52
# 1475015       52
# 120762452     50
# 2856748       49
# 205031545     49
# 190921808     47
# 26377263      43
# 2119276       39
# 19303369      37
# 119669058     34
# 25237492      34
# Name: host_id, dtype: int64

# %% [markdown]
# # ⚡Creating a data frame of top 20 host id

# %%
df_top=pd.DataFrame(data=top_host_id)
df_top.reset_index(inplace=True)
df_top.rename(columns={'index':'Host_id','host_id':'counts'},inplace=True)
df_top
# Out:
#       Host_id  counts
# 0   219517861     327
# 1   107434423     232
# 2    30283594     121
# 3   137358866     103
# 4    16098958      96
# 5    12243051      96
# 6    61391963      91
# 7    22541573      87
# 8   200380610      65
# 9     7503643      52
# 10    1475015      52
# 11  120762452      50
# 12    2856748      49
# 13  205031545      49
# 14  190921808      47
# 15   26377263      43
# 16    2119276      39
# 17   19303369      37
# 18  119669058      34
# 19   25237492      34

# %% [markdown]
# ## By using above data we can plot a graph for easy visual understanding

# %%
fig_5=sns.barplot(x='Host_id',y='counts',data=df_top)
fig_5.set_title('Hosts with the most listings in NYC')
fig_5.set_ylabel('Count of listings')
fig_5.set_xlabel('Host IDs')
fig_5.set_xticklabels(fig_5.get_xticklabels(), rotation=45)
plt.show()

# %% [markdown]
# From the above Bar Chart we come to know that 219517861 host_id have highest stays

# %% [markdown]
# # **⚡ TOP 20 EXPENSIVE NEIGHBOURHOOD BASED ON THE AVERAGE PRICE**

# %%
Expen_neigh = df.groupby(["neighbourhood"])['price'].aggregate(np.median).reset_index().sort_values(['price'],ascending=False)
Expen_neigh
# Out:
#       neighbourhood  price
# 82   Fort Wadsworth  800.0
# 219         Woodrow  700.0
# 197         Tribeca  295.0
# 139        Neponsit  274.0
# 144            NoHo  250.0
# ..              ...    ...
# 50           Corona   40.0
# 102     Hunts Point   40.0
# 142  New Dorp Beach   40.0
# 32      Castle Hill   39.0
# 46          Concord   34.5
#
# [221 rows x 2 columns]

# %%
fig_6=sns.barplot(x='neighbourhood',y='price',data=Expen_neigh[:20])
fig_6.set_title('TOP 10 EXPENSIVE NEIGHBOURHOOD BASED ON THE AVERAGE PRICE')
fig_6.set_ylabel('Average Price')
fig_6.set_xlabel('NEIGHBOURHOOD')
fig_6.set_xticklabels(fig_6.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, 'Fort Wadsworth'),
#  Text(0, 0, 'Woodrow'),
#  Text(0, 0, 'Tribeca'),
#  Text(0, 0, 'Neponsit'),
#  Text(0, 0, 'NoHo'),
#  Text(0, 0, 'Willowbrook'),
#  Text(0, 0, 'Flatiron District'),
#  Text(0, 0, 'Midtown'),
#  Text(0, 0, 'Financial District'),
#  Text(0, 0, 'West Village'),
#  Text(0, 0, 'Chelsea'),
#  Text(0, 0, 'SoHo'),
#  Text(0, 0, 'Greenwich Village'),
#  Text(0, 0, 'Battery Park City'),
#  Text(0, 0, 'Breezy Point'),
#  Text(0, 0, 'Murray Hill'),
#  Text(0, 0, 'Theater District'),
#  Text(0, 0, 'DUMBO'),
#  Text(0, 0, 'Nolita'),
#  Text(0, 0, 'Vinegar Hill')]

# %% [markdown]
# #**⚡ TOP 20 INEXPENSIVE NEIGHBOURHOOD BASED ON THE AVERAGE PRICE**

# %%
fig_6=sns.barplot(x='neighbourhood',y='price',data=Expen_neigh[-20:])
fig_6.set_title('TOP 10 EXPENSIVE NEIGHBOURHOOD BASED ON THE AVERAGE PRICE')
fig_6.set_ylabel('Average Price')
fig_6.set_xlabel('NEIGHBOURHOOD')
fig_6.set_xticklabels(fig_6.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, 'New Brighton'),
#  Text(0, 0, 'Borough Park'),
#  Text(0, 0, 'Olinville'),
#  Text(0, 0, 'Belmont'),
#  Text(0, 0, 'Woodhaven'),
#  Text(0, 0, 'Morris Heights'),
#  Text(0, 0, 'Little Neck'),
#  Text(0, 0, 'Van Nest'),
#  Text(0, 0, 'Port Richmond'),
#  Text(0, 0, 'Bronxdale'),
#  Text(0, 0, 'Whitestone'),
#  Text(0, 0, 'Soundview'),
#  Text(0, 0, 'Mount Eden'),
#  Text(0, 0, "Bull's Head"),
#  Text(0, 0, 'Tremont'),
#  Text(0, 0, 'Corona'),
#  Text(0, 0, 'Hunts Point'),
#  Text(0, 0, 'New Dorp Beach'),
#  Text(0, 0, 'Castle Hill'),
#  Text(0, 0, 'Concord')]

# %% [markdown]
# # ⚔️**CONCLUSION**

# %% [markdown]
# **Throughout the analysis our goal was to investigate each variable and uncover as much hidden facts about the data as possible.Though it is also true that we spent most time on price variable and its relationship with other variables since most of the important information regarding traffic density and customer preference are correlated with price.**

# %% [markdown]
# **This is the end of our EDA Project as there is no useful Data and insights left to extract.**
